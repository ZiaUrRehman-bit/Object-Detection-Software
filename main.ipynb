# %% [markdown]
# ## **<center><font style="color:rgb(100,109,254)">Object Detection Software</font> </center>**
# #### **<center><font style="color:rgb(100,109,254)">By Engr. Zia Ur Rehman</font> </center>**

# %% [markdown]
# ### 1. Import Libraries

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %% [markdown]
# #### 1.1 Load DNN model YOLOV4-tiny for Object Detection
#
# We need two files, one is configuration and other is weights file of the model.
#
# #### **<font style="color:rgb(255,0,0)">Link: Download the model and wieght files from this link</font>**
# https://github.com/ZiaUrRehman-bit/Object-Detection-Software/tree/master/dnn_model

# %%
net = cv2.dnn.readNet("dnn_model/yolov4-tiny.weights", "dnn_model/yolov4-tiny.cfg")

# %%
model = cv2.dnn_DetectionModel(net)

# %%
model.setInputParams(size = (320, 320), scale = 1/255)

# %% [markdown]
# ### 2. Capture Frame from Webcam

# %%
cap = cv2.VideoCapture(0)

# %% [markdown]
# ### 3. Object Detection

# %%
def detectObject(frame):
    
    clasIds, score, boundingBox = model.detect(frame)

    return clasIds, score, boundingBox

# %%
print(round(12.7777, 2))
# Out:
# 12.78

# %% [markdown]
# ### 4. Read the frames and detect the objects using above created function

# %%
cap = cv2.VideoCapture(1)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox

        cv2.putText(frame, f"Class Id: {classId}, Score: {score}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.5121554]
# Boundbox: [[282  68 112 266]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.5075037]
# Boundbox: [[295  93 105 271]]
# Class Id: [39]
# Socres: [0.5075037]
# Boundbox: [[295  93 105 271]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.56137645]
# Boundbox: [[301 108 107 271]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5128221]
# Boundbox: [[  0   0 325 353]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.6960914]
# Boundbox: [[242  29 140 292]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.74654335]
# Boundbox: [[235  29 138 304]]
# Class Id: [39]
# Socres: [0.50577027]
# Boundbox: [[223  24 145 295]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.55610687]
# Boundbox: [[219  25 140 297]]
# Class Id: [39]
# Socres: [0.573268]
# Boundbox: [[216  23 148 285]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.52525896]
# Boundbox: [[210  52 138 300]]
# Class Id: [39]
# Socres: [0.58630335]
# Boundbox: [[216  58 134 296]]
# Class Id: [39]
# Socres: [0.69667184]
# Boundbox: [[220  62 136 291]]
# Class Id: [39]
# Socres: [0.6117827]
# Boundbox: [[221  58 137 299]]
# Class Id: [39]
# Socres: [0.6162283]
# Boundbox: [[221  66 135 294]]
# Class Id: [39]
# Socres: [0.63389844]
# Boundbox: [[221  68 134 293]]
# Class Id: [39]
# Socres: [0.73436964]
# Boundbox: [[222  67 133 292]]
# Class Id: [39]
# Socres: [0.6440688]
# Boundbox: [[220  66 138 293]]
# Class Id: [39]
# Socres: [0.6440688]
# Boundbox: [[220  66 138 293]]
# Class Id: [39]
# Socres: [0.6440688]
# Boundbox: [[220  66 138 293]]
# Class Id: [39]
# Socres: [0.64758885]
# Boundbox: [[220  69 134 289]]
# Class Id: [39]
# Socres: [0.7132924]
# Boundbox: [[218  63 140 295]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [39]
# Socres: [0.7092465]
# Boundbox: [[226  65 131 293]]
# Class Id: [39]
# Socres: [0.6223482]
# Boundbox: [[225  65 131 292]]
# Class Id: [39]
# Socres: [0.67089796]
# Boundbox: [[224  64 134 296]]
# Class Id: [39]
# Socres: [0.5752027]
# Boundbox: [[222  64 136 292]]
# Class Id: [39]
# Socres: [0.61548793]
# Boundbox: [[223  62 136 294]]
# Class Id: [39]
# Socres: [0.52355367]
# Boundbox: [[227  60 130 300]]
# Class Id: [39]
# Socres: [0.7241311]
# Boundbox: [[229  64 131 301]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
