# %% [markdown]
# ## **<center><font style="color:rgb(100,109,254)">Object Detection Software</font> </center>**
# #### **<center><font style="color:rgb(100,109,254)">By Engr. Zia Ur Rehman</font> </center>**

# %% [markdown]
# ### 1. Import Libraries

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %% [markdown]
# #### 1.1 Load DNN model YOLOV4-tiny for Object Detection
#
# We need two files, one is configuration and other is weights file of the model.
#
# #### **<font style="color:rgb(255,0,0)">Link: Download the model and wieght files from this link</font>**
# https://github.com/ZiaUrRehman-bit/Object-Detection-Software/tree/master/dnn_model

# %%
net = cv2.dnn.readNet("dnn_model/yolov4-tiny.weights", "dnn_model/yolov4-tiny.cfg")

# %%
model = cv2.dnn_DetectionModel(net)

# %%
model.setInputParams(size = (320, 320), scale = 1/255)

# %% [markdown]
# ### 2. Capture Frame from Webcam

# %%
cap = cv2.VideoCapture(0)

# %% [markdown]
# ### 3. Object Detection

# %%
def detectObject(frame):
    
    clasIds, score, boundingBox = model.detect(frame)

    return clasIds, score, boundingBox

# %%
print(round(12.7777, 2))
# Out:
# 12.78

# %% [markdown]
# ### 4. Read the frames and detect the objects using above created function

# %%
cap = cv2.VideoCapture(0)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox

        cv2.putText(frame, f"Class Id: {classId}, Score: {score}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Class Id: [0]
# Socres: [0.77039737]
# Boundbox: [[ 57 120 573 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.8117586]
# Boundbox: [[ 77 121 540 359]]
# Class Id: [0]
# Socres: [0.83188474]
# Boundbox: [[ 80 130 536 350]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.72738826]
# Boundbox: [[ 83 124 532 356]]
# Class Id: [0]
# Socres: [0.6097629]
# Boundbox: [[ 74 125 546 352]]
# Class Id: [0]
# Socres: [0.7401927]
# Boundbox: [[ 75 120 540 360]]
# Class Id: [0]
# Socres: [0.61131805]
# Boundbox: [[ 74 128 546 352]]
# Class Id: [0]
# Socres: [0.8529264]
# Boundbox: [[ 77 129 543 351]]
# Class Id: [0]
# Socres: [0.73898494]
# Boundbox: [[ 70 117 551 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.74097073]
# Boundbox: [[ 71 126 551 354]]
# Class Id: [0]
# Socres: [0.6381557]
# Boundbox: [[ 71 120 553 360]]
# Class Id: [0]
# Socres: [0.6645439]
# Boundbox: [[ 70 124 553 356]]
# Class Id: [0]
# Socres: [0.5213294]
# Boundbox: [[ 65 125 564 353]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.65285486]
# Boundbox: [[ 72 120 554 360]]
# Class Id: [0]
# Socres: [0.7255675]
# Boundbox: [[ 75 125 544 355]]
# Class Id: [0]
# Socres: [0.7425607]
# Boundbox: [[ 77 112 538 368]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.76797056]
# Boundbox: [[ 68 126 559 354]]
# Class Id: [0]
# Socres: [0.6501262]
# Boundbox: [[ 74 123 546 357]]
# Class Id: [0]
# Socres: [0.64748955]
# Boundbox: [[ 75 128 544 352]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.85719645]
# Boundbox: [[ 88 117 524 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5795976]
# Boundbox: [[ 77 114 543 366]]
# Class Id: [0]
# Socres: [0.5180404]
# Boundbox: [[ 76 119 544 361]]
# Class Id: [0]
# Socres: [0.7101453]
# Boundbox: [[ 71 122 553 358]]
# Class Id: [0]
# Socres: [0.6129747]
# Boundbox: [[ 74 115 545 365]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6149105]
# Boundbox: [[ 85 118 531 362]]
# Class Id: [0]
# Socres: [0.57803226]
# Boundbox: [[ 78 118 541 362]]
# Class Id: [0]
# Socres: [0.61878437]
# Boundbox: [[ 81 123 540 357]]
# Class Id: [0]
# Socres: [0.5612193]
# Boundbox: [[ 70 121 559 359]]
# Class Id: [0]
# Socres: [0.61044824]
# Boundbox: [[ 71 117 556 363]]
# Class Id: [0]
# Socres: [0.57220924]
# Boundbox: [[ 72 123 555 357]]
# Class Id: [0]
# Socres: [0.5673502]
# Boundbox: [[ 83 123 530 357]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6500037]
# Boundbox: [[ 77 126 546 350]]
# Class Id: [0]
# Socres: [0.79550666]
# Boundbox: [[ 74 116 543 364]]
# Class Id: [0]
# Socres: [0.6869557]
# Boundbox: [[ 65 120 550 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.8582169]
# Boundbox: [[ 75 125 548 355]]
# Class Id: [0]
# Socres: [0.84876794]
# Boundbox: [[ 79 120 538 360]]
# Class Id: [0]
# Socres: [0.80856764]
# Boundbox: [[ 80 122 540 358]]
# Class Id: [0]
# Socres: [0.7431772]
# Boundbox: [[ 78 122 540 358]]
# Class Id: [0]
# Socres: [0.84482926]
# Boundbox: [[ 68 129 562 351]]
# Class Id: [0]
# Socres: [0.75413245]
# Boundbox: [[ 78 124 541 356]]
# Class Id: [0]
# Socres: [0.7307504]
# Boundbox: [[ 78 123 543 357]]
# Class Id: [0]
# Socres: [0.7566437]
# Boundbox: [[ 72 124 552 356]]
# Class Id: [0]
# Socres: [0.73571414]
# Boundbox: [[ 73 124 548 356]]
# Class Id: [0]
# Socres: [0.74838656]
# Boundbox: [[ 79 123 539 357]]
# Class Id: [0]
# Socres: [0.5577537]
# Boundbox: [[ 91 121 520 359]]
# Class Id: [0]
# Socres: [0.7784738]
# Boundbox: [[ 65 122 566 358]]
# Class Id: [0]
# Socres: [0.7421049]
# Boundbox: [[ 84 112 529 368]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5017751]
# Boundbox: [[ 71 121 552 359]]
# Class Id: [0]
# Socres: [0.6876076]
# Boundbox: [[ 72 119 550 361]]
# Class Id: [0]
# Socres: [0.6030554]
# Boundbox: [[ 78 128 539 352]]
# Class Id: [0]
# Socres: [0.73359257]
# Boundbox: [[ 81 124 536 356]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.75316346]
# Boundbox: [[ 73 126 552 354]]
# Class Id: [0]
# Socres: [0.9114215]
# Boundbox: [[ 77 126 545 354]]
# Class Id: [0]
# Socres: [0.74648505]
# Boundbox: [[ 84 129 534 351]]
# Class Id: [0]
# Socres: [0.5329514]
# Boundbox: [[ 76 120 543 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6160673]
# Boundbox: [[ 68 116 561 364]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6222467]
# Boundbox: [[ 76 119 547 361]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.67107725]
# Boundbox: [[ 70 118 558 362]]
# Class Id: [0]
# Socres: [0.6530852]
# Boundbox: [[148   4  41  53]]
# Class Id: [0 0]
# Socres: [0.63578343 0.5190951 ]
# Boundbox: [[ 71 122 550 358]
#  [148   3  41  54]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.7805074]
# Boundbox: [[ 75 121 544 359]]
# Class Id: [0 0]
# Socres: [0.61536056 0.5046799 ]
# Boundbox: [[ 78 117 541 363]
#  [146   4  42  53]]
# Class Id: [0 0]
# Socres: [0.7315208  0.53494847]
# Boundbox: [[ 66 121 561 359]
#  [147   4  42  52]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.6157172 0.6992766]
# Boundbox: [[ 73 125 550 355]
#  [148   4  41  52]]
# Class Id: [0]
# Socres: [0.5698712]
# Boundbox: [[149   6  39  51]]
# Class Id: [0]
# Socres: [0.55789804]
# Boundbox: [[148   4  41  55]]
# Class Id: [0 0]
# Socres: [0.50421715 0.57770044]
# Boundbox: [[ 73 120 548 360]
#  [148   5  41  53]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [56 56 56]
# Socres: [0.59302276 0.51465374 0.6189368 ]
# Boundbox: [[ 67 315 203 161]
#  [ 27 311 250 166]
#  [ 69 317 202 158]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5607909]
# Boundbox: [[107 109 494 371]]
# Class Id: [0]
# Socres: [0.503933]
# Boundbox: [[106 117 494 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5332336]
# Boundbox: [[ 87 119 531 361]]
# Class Id: [56]
# Socres: [0.5142446]
# Boundbox: [[  4 186 197 286]]
# Class Id: [0]
# Socres: [0.6531632]
# Boundbox: [[ 76 112 541 368]]
# Class Id: [0]
# Socres: [0.5620347]
# Boundbox: [[ 71 118 547 362]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.690259]
# Boundbox: [[ 78 116 533 364]]
# Class Id: [0]
# Socres: [0.6410486]
# Boundbox: [[ 65 125 554 355]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5475226]
# Boundbox: [[ 61 123 193 314]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.64249516]
# Boundbox: [[ 74 126 184 306]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5831327]
# Boundbox: [[111 132 180 299]]
# Class Id: [67]
# Socres: [0.5115463]
# Boundbox: [[ 90 140 220 310]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.59684086]
# Boundbox: [[ 86 129 177 305]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.74665046]
# Boundbox: [[ 69 139 193 320]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5803484]
# Boundbox: [[ 69 139 197 320]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.6010651]
# Boundbox: [[ 96 138 219 325]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.74566066]
# Boundbox: [[ 99 144 208 316]]
# Class Id: [67]
# Socres: [0.7749511]
# Boundbox: [[112 146 200 304]]
# Class Id: [67]
# Socres: [0.575049]
# Boundbox: [[111 143 196 312]]
# Class Id: [67]
# Socres: [0.90182316]
# Boundbox: [[120 141 186 314]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.71616715]
# Boundbox: [[116 146 192 309]]
# Class Id: [67]
# Socres: [0.78059196]
# Boundbox: [[111 142 199 314]]
# Class Id: [67]
# Socres: [0.65981174]
# Boundbox: [[118 150 187 302]]
# Class Id: [67]
# Socres: [0.8480885]
# Boundbox: [[113 141 192 316]]
# Class Id: [67]
# Socres: [0.601478]
# Boundbox: [[107 145 203 308]]
# Class Id: [67]
# Socres: [0.6730315]
# Boundbox: [[105 144 204 313]]
# Class Id: [67]
# Socres: [0.8817916]
# Boundbox: [[116 144 191 306]]
# Class Id: [67]
# Socres: [0.8562322]
# Boundbox: [[123 144 179 307]]
# Class Id: [67]
# Socres: [0.8124848]
# Boundbox: [[117 139 189 312]]
# Class Id: [67]
# Socres: [0.73737806]
# Boundbox: [[114 144 193 310]]
# Class Id: [67]
# Socres: [0.5806618]
# Boundbox: [[116 141 191 312]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67 67]
# Socres: [0.60040265 0.5875012 ]
# Boundbox: [[ 19 131 169 305]
#  [ 14 146 171 304]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55410695]
# Boundbox: [[ 71 111 553 369]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5345298]
# Boundbox: [[146   3  43  54]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50537026]
# Boundbox: [[146   4  42  53]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5387469]
# Boundbox: [[ 38  67 602 403]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6522976]
# Boundbox: [[ 85 104 525 376]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.52713794]
# Boundbox: [[ 48  49 585 431]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5195879]
# Boundbox: [[ 54  57 570 423]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5720518]
# Boundbox: [[ 88  57 510 422]]
# Class Id: [0]
# Socres: [0.6781065]
# Boundbox: [[ 84  54 515 426]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6180127]
# Boundbox: [[ 91  68 514 412]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5552756]
# Boundbox: [[ 79  62 525 414]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50633395]
# Boundbox: [[ 70  63 541 416]]
# Class Id: [0]
# Socres: [0.5057951]
# Boundbox: [[ 66  64 549 416]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6327149]
# Boundbox: [[ 86  55 518 425]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.59241486]
# Boundbox: [[ 72  54 535 426]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.64137954]
# Boundbox: [[ 63  66 555 414]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5911337]
# Boundbox: [[ 52  58 575 422]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()

# %% [markdown]
# ### 5. Get the Class Name and display on frame

# %%
cap = cv2.VideoCapture(0)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox

        cv2.putText(frame, f"Class Id: {classId}, Score: {score}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
