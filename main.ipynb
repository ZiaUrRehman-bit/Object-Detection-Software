# %% [markdown]
# ## **<center><font style="color:rgb(100,109,254)">Object Detection Software</font> </center>**
# #### **<center><font style="color:rgb(100,109,254)">By Engr. Zia Ur Rehman</font> </center>**

# %% [markdown]
# ### 1. Import Libraries

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %% [markdown]
# #### 1.1 Load DNN model YOLOV4-tiny for Object Detection
#
# We need two files, one is configuration and other is weights file of the model.
#
# #### **<font style="color:rgb(255,0,0)">Link: Download the model and wieght files from this link</font>**
# https://github.com/ZiaUrRehman-bit/Object-Detection-Software/tree/master/dnn_model

# %%
net = cv2.dnn.readNet("dnn_model/yolov4-tiny.weights", "dnn_model/yolov4-tiny.cfg")

# %%
model = cv2.dnn_DetectionModel(net)

# %%
model.setInputParams(size = (320, 320), scale = 1/255)

# %% [markdown]
# ### 2. Capture Frame from Webcam

# %%
cap = cv2.VideoCapture(0)

# %% [markdown]
# ### 3. Object Detection

# %%
def detectObject(frame):
    
    clasIds, score, boundingBox = model.detect(frame)

    return clasIds, score, boundingBox

# %%
print(round(12.7777, 2))
# Out:
# 12.78

# %% [markdown]
# ### 4. Read the frames and detect the objects using above created function

# %%
cap = cv2.VideoCapture(0)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox

        cv2.putText(frame, f"Class Id: {classId}, Score: {score}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Class Id: [0]
# Socres: [0.77039737]
# Boundbox: [[ 57 120 573 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.8117586]
# Boundbox: [[ 77 121 540 359]]
# Class Id: [0]
# Socres: [0.83188474]
# Boundbox: [[ 80 130 536 350]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.72738826]
# Boundbox: [[ 83 124 532 356]]
# Class Id: [0]
# Socres: [0.6097629]
# Boundbox: [[ 74 125 546 352]]
# Class Id: [0]
# Socres: [0.7401927]
# Boundbox: [[ 75 120 540 360]]
# Class Id: [0]
# Socres: [0.61131805]
# Boundbox: [[ 74 128 546 352]]
# Class Id: [0]
# Socres: [0.8529264]
# Boundbox: [[ 77 129 543 351]]
# Class Id: [0]
# Socres: [0.73898494]
# Boundbox: [[ 70 117 551 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.74097073]
# Boundbox: [[ 71 126 551 354]]
# Class Id: [0]
# Socres: [0.6381557]
# Boundbox: [[ 71 120 553 360]]
# Class Id: [0]
# Socres: [0.6645439]
# Boundbox: [[ 70 124 553 356]]
# Class Id: [0]
# Socres: [0.5213294]
# Boundbox: [[ 65 125 564 353]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.65285486]
# Boundbox: [[ 72 120 554 360]]
# Class Id: [0]
# Socres: [0.7255675]
# Boundbox: [[ 75 125 544 355]]
# Class Id: [0]
# Socres: [0.7425607]
# Boundbox: [[ 77 112 538 368]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.76797056]
# Boundbox: [[ 68 126 559 354]]
# Class Id: [0]
# Socres: [0.6501262]
# Boundbox: [[ 74 123 546 357]]
# Class Id: [0]
# Socres: [0.64748955]
# Boundbox: [[ 75 128 544 352]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.85719645]
# Boundbox: [[ 88 117 524 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5795976]
# Boundbox: [[ 77 114 543 366]]
# Class Id: [0]
# Socres: [0.5180404]
# Boundbox: [[ 76 119 544 361]]
# Class Id: [0]
# Socres: [0.7101453]
# Boundbox: [[ 71 122 553 358]]
# Class Id: [0]
# Socres: [0.6129747]
# Boundbox: [[ 74 115 545 365]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6149105]
# Boundbox: [[ 85 118 531 362]]
# Class Id: [0]
# Socres: [0.57803226]
# Boundbox: [[ 78 118 541 362]]
# Class Id: [0]
# Socres: [0.61878437]
# Boundbox: [[ 81 123 540 357]]
# Class Id: [0]
# Socres: [0.5612193]
# Boundbox: [[ 70 121 559 359]]
# Class Id: [0]
# Socres: [0.61044824]
# Boundbox: [[ 71 117 556 363]]
# Class Id: [0]
# Socres: [0.57220924]
# Boundbox: [[ 72 123 555 357]]
# Class Id: [0]
# Socres: [0.5673502]
# Boundbox: [[ 83 123 530 357]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6500037]
# Boundbox: [[ 77 126 546 350]]
# Class Id: [0]
# Socres: [0.79550666]
# Boundbox: [[ 74 116 543 364]]
# Class Id: [0]
# Socres: [0.6869557]
# Boundbox: [[ 65 120 550 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.8582169]
# Boundbox: [[ 75 125 548 355]]
# Class Id: [0]
# Socres: [0.84876794]
# Boundbox: [[ 79 120 538 360]]
# Class Id: [0]
# Socres: [0.80856764]
# Boundbox: [[ 80 122 540 358]]
# Class Id: [0]
# Socres: [0.7431772]
# Boundbox: [[ 78 122 540 358]]
# Class Id: [0]
# Socres: [0.84482926]
# Boundbox: [[ 68 129 562 351]]
# Class Id: [0]
# Socres: [0.75413245]
# Boundbox: [[ 78 124 541 356]]
# Class Id: [0]
# Socres: [0.7307504]
# Boundbox: [[ 78 123 543 357]]
# Class Id: [0]
# Socres: [0.7566437]
# Boundbox: [[ 72 124 552 356]]
# Class Id: [0]
# Socres: [0.73571414]
# Boundbox: [[ 73 124 548 356]]
# Class Id: [0]
# Socres: [0.74838656]
# Boundbox: [[ 79 123 539 357]]
# Class Id: [0]
# Socres: [0.5577537]
# Boundbox: [[ 91 121 520 359]]
# Class Id: [0]
# Socres: [0.7784738]
# Boundbox: [[ 65 122 566 358]]
# Class Id: [0]
# Socres: [0.7421049]
# Boundbox: [[ 84 112 529 368]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5017751]
# Boundbox: [[ 71 121 552 359]]
# Class Id: [0]
# Socres: [0.6876076]
# Boundbox: [[ 72 119 550 361]]
# Class Id: [0]
# Socres: [0.6030554]
# Boundbox: [[ 78 128 539 352]]
# Class Id: [0]
# Socres: [0.73359257]
# Boundbox: [[ 81 124 536 356]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.75316346]
# Boundbox: [[ 73 126 552 354]]
# Class Id: [0]
# Socres: [0.9114215]
# Boundbox: [[ 77 126 545 354]]
# Class Id: [0]
# Socres: [0.74648505]
# Boundbox: [[ 84 129 534 351]]
# Class Id: [0]
# Socres: [0.5329514]
# Boundbox: [[ 76 120 543 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6160673]
# Boundbox: [[ 68 116 561 364]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6222467]
# Boundbox: [[ 76 119 547 361]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.67107725]
# Boundbox: [[ 70 118 558 362]]
# Class Id: [0]
# Socres: [0.6530852]
# Boundbox: [[148   4  41  53]]
# Class Id: [0 0]
# Socres: [0.63578343 0.5190951 ]
# Boundbox: [[ 71 122 550 358]
#  [148   3  41  54]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.7805074]
# Boundbox: [[ 75 121 544 359]]
# Class Id: [0 0]
# Socres: [0.61536056 0.5046799 ]
# Boundbox: [[ 78 117 541 363]
#  [146   4  42  53]]
# Class Id: [0 0]
# Socres: [0.7315208  0.53494847]
# Boundbox: [[ 66 121 561 359]
#  [147   4  42  52]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.6157172 0.6992766]
# Boundbox: [[ 73 125 550 355]
#  [148   4  41  52]]
# Class Id: [0]
# Socres: [0.5698712]
# Boundbox: [[149   6  39  51]]
# Class Id: [0]
# Socres: [0.55789804]
# Boundbox: [[148   4  41  55]]
# Class Id: [0 0]
# Socres: [0.50421715 0.57770044]
# Boundbox: [[ 73 120 548 360]
#  [148   5  41  53]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [56 56 56]
# Socres: [0.59302276 0.51465374 0.6189368 ]
# Boundbox: [[ 67 315 203 161]
#  [ 27 311 250 166]
#  [ 69 317 202 158]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5607909]
# Boundbox: [[107 109 494 371]]
# Class Id: [0]
# Socres: [0.503933]
# Boundbox: [[106 117 494 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5332336]
# Boundbox: [[ 87 119 531 361]]
# Class Id: [56]
# Socres: [0.5142446]
# Boundbox: [[  4 186 197 286]]
# Class Id: [0]
# Socres: [0.6531632]
# Boundbox: [[ 76 112 541 368]]
# Class Id: [0]
# Socres: [0.5620347]
# Boundbox: [[ 71 118 547 362]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.690259]
# Boundbox: [[ 78 116 533 364]]
# Class Id: [0]
# Socres: [0.6410486]
# Boundbox: [[ 65 125 554 355]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5475226]
# Boundbox: [[ 61 123 193 314]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.64249516]
# Boundbox: [[ 74 126 184 306]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5831327]
# Boundbox: [[111 132 180 299]]
# Class Id: [67]
# Socres: [0.5115463]
# Boundbox: [[ 90 140 220 310]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.59684086]
# Boundbox: [[ 86 129 177 305]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.74665046]
# Boundbox: [[ 69 139 193 320]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5803484]
# Boundbox: [[ 69 139 197 320]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.6010651]
# Boundbox: [[ 96 138 219 325]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.74566066]
# Boundbox: [[ 99 144 208 316]]
# Class Id: [67]
# Socres: [0.7749511]
# Boundbox: [[112 146 200 304]]
# Class Id: [67]
# Socres: [0.575049]
# Boundbox: [[111 143 196 312]]
# Class Id: [67]
# Socres: [0.90182316]
# Boundbox: [[120 141 186 314]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.71616715]
# Boundbox: [[116 146 192 309]]
# Class Id: [67]
# Socres: [0.78059196]
# Boundbox: [[111 142 199 314]]
# Class Id: [67]
# Socres: [0.65981174]
# Boundbox: [[118 150 187 302]]
# Class Id: [67]
# Socres: [0.8480885]
# Boundbox: [[113 141 192 316]]
# Class Id: [67]
# Socres: [0.601478]
# Boundbox: [[107 145 203 308]]
# Class Id: [67]
# Socres: [0.6730315]
# Boundbox: [[105 144 204 313]]
# Class Id: [67]
# Socres: [0.8817916]
# Boundbox: [[116 144 191 306]]
# Class Id: [67]
# Socres: [0.8562322]
# Boundbox: [[123 144 179 307]]
# Class Id: [67]
# Socres: [0.8124848]
# Boundbox: [[117 139 189 312]]
# Class Id: [67]
# Socres: [0.73737806]
# Boundbox: [[114 144 193 310]]
# Class Id: [67]
# Socres: [0.5806618]
# Boundbox: [[116 141 191 312]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67 67]
# Socres: [0.60040265 0.5875012 ]
# Boundbox: [[ 19 131 169 305]
#  [ 14 146 171 304]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55410695]
# Boundbox: [[ 71 111 553 369]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5345298]
# Boundbox: [[146   3  43  54]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50537026]
# Boundbox: [[146   4  42  53]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5387469]
# Boundbox: [[ 38  67 602 403]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6522976]
# Boundbox: [[ 85 104 525 376]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.52713794]
# Boundbox: [[ 48  49 585 431]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5195879]
# Boundbox: [[ 54  57 570 423]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5720518]
# Boundbox: [[ 88  57 510 422]]
# Class Id: [0]
# Socres: [0.6781065]
# Boundbox: [[ 84  54 515 426]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6180127]
# Boundbox: [[ 91  68 514 412]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5552756]
# Boundbox: [[ 79  62 525 414]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50633395]
# Boundbox: [[ 70  63 541 416]]
# Class Id: [0]
# Socres: [0.5057951]
# Boundbox: [[ 66  64 549 416]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6327149]
# Boundbox: [[ 86  55 518 425]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.59241486]
# Boundbox: [[ 72  54 535 426]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.64137954]
# Boundbox: [[ 63  66 555 414]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5911337]
# Boundbox: [[ 52  58 575 422]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()

# %% [markdown]
# ### 5. Get the Class Name and display on frame

# %%
classNamesList = []

with open("dnn_model/classes.txt", "r") as fileObject:
    for className in fileObject.readlines():
        className = className.strip()
        classNamesList.append(className)

# print(classNamesList)
cap = cv2.VideoCapture(0)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox
        objectName = classNamesList[classId]
        cv2.putText(frame, f"{objectName}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Class Id: [0]
# Socres: [0.7147261]
# Boundbox: [[ 91 133 522 342]]
# Class Id: [0]
# Socres: [0.78451794]
# Boundbox: [[ 84 142 535 328]]
# Class Id: [0]
# Socres: [0.79734993]
# Boundbox: [[ 82 145 538 325]]
# Class Id: [0]
# Socres: [0.762822]
# Boundbox: [[ 86 139 533 329]]
# Class Id: [0]
# Socres: [0.62802035]
# Boundbox: [[ 67 139 560 333]]
# Class Id: [0]
# Socres: [0.7394209]
# Boundbox: [[ 80 147 541 321]]
# Class Id: [0]
# Socres: [0.79273856]
# Boundbox: [[ 74 128 542 351]]
# Class Id: [0]
# Socres: [0.83667886]
# Boundbox: [[ 70 138 551 335]]
# Class Id: [0]
# Socres: [0.6967262]
# Boundbox: [[ 74 138 549 330]]
# Class Id: [0]
# Socres: [0.75715894]
# Boundbox: [[ 73 137 548 333]]
# Class Id: [0]
# Socres: [0.64866275]
# Boundbox: [[ 71 134 552 341]]
# Class Id: [0]
# Socres: [0.7549699]
# Boundbox: [[ 77 146 540 316]]
# Class Id: [0]
# Socres: [0.78743297]
# Boundbox: [[ 75 138 545 339]]
# Class Id: [0]
# Socres: [0.71843386]
# Boundbox: [[ 64 141 556 327]]
# Class Id: [0]
# Socres: [0.77274966]
# Boundbox: [[ 63 145 564 319]]
# Class Id: [0]
# Socres: [0.8443038]
# Boundbox: [[ 72 138 544 336]]
# Class Id: [0]
# Socres: [0.76166004]
# Boundbox: [[ 74 142 539 327]]
# Class Id: [0]
# Socres: [0.6569215]
# Boundbox: [[ 67 137 552 334]]
# Class Id: [0]
# Socres: [0.83074373]
# Boundbox: [[ 72 139 552 330]]
# Class Id: [0]
# Socres: [0.65136397]
# Boundbox: [[ 71 134 549 338]]
# Class Id: [0]
# Socres: [0.75276333]
# Boundbox: [[ 83 141 535 324]]
# Class Id: [0]
# Socres: [0.6162374]
# Boundbox: [[ 68 143 557 319]]
# Class Id: [0]
# Socres: [0.8590901]
# Boundbox: [[ 73 148 555 315]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5535972]
# Boundbox: [[ 81 132 534 339]]
# Class Id: [0]
# Socres: [0.8020524]
# Boundbox: [[ 64 131 564 348]]
# Class Id: [0]
# Socres: [0.6036331]
# Boundbox: [[ 70 132 554 340]]
# Class Id: [0]
# Socres: [0.571109]
# Boundbox: [[ 60 134 564 339]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.71674937]
# Boundbox: [[ 72 137 555 339]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5275384]
# Boundbox: [[145  15  39  50]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6555726]
# Boundbox: [[145  11  39  49]]
# Class Id: [0]
# Socres: [0.5049838]
# Boundbox: [[143  14  43  48]]
# Class Id: [0]
# Socres: [0.50477743]
# Boundbox: [[141  11  42  51]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.5873598]
# Boundbox: [[246 142 187 332]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.526706]
# Boundbox: [[225 154 390 322]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5300304]
# Boundbox: [[229 126 377 354]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5976255]
# Boundbox: [[223 135 388 343]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.67773044]
# Boundbox: [[ 36 118 202 321]]
# Class Id: [67]
# Socres: [0.63441265]
# Boundbox: [[ 50 119 182 322]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5113642]
# Boundbox: [[ 76 113 175 334]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55438614]
# Boundbox: [[260 137 320 343]]
# Class Id: [0]
# Socres: [0.5210869]
# Boundbox: [[269 134 304 346]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.62048376]
# Boundbox: [[121 127 215 348]]
# Class Id: [67]
# Socres: [0.6087841]
# Boundbox: [[123 116 207 364]]
# Class Id: [67]
# Socres: [0.63589394]
# Boundbox: [[118 116 197 363]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.5627888]
# Boundbox: [[269 154 189 308]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.54703265]
# Boundbox: [[239 136 362 343]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5538012]
# Boundbox: [[262 126 317 354]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.58521014]
# Boundbox: [[119 117 230 352]]
# Class Id: [67]
# Socres: [0.55426556]
# Boundbox: [[124 117 226 358]]
# Class Id: [67]
# Socres: [0.7322996]
# Boundbox: [[119 114 234 365]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67 67]
# Socres: [0.59381276 0.8284026 ]
# Boundbox: [[199 103 205 353]
#  [201 113 198 366]]
# Class Id: [67]
# Socres: [0.6043418]
# Boundbox: [[204 121 177 357]]
# Class Id: [67]
# Socres: [0.61719775]
# Boundbox: [[201 131 175 337]]
# Class Id: [67]
# Socres: [0.8917872]
# Boundbox: [[198 139 175 323]]
# Class Id: [67]
# Socres: [0.58907706]
# Boundbox: [[194 141 171 315]]
# Class Id: [67]
# Socres: [0.76209635]
# Boundbox: [[189 138 162 316]]
# Class Id: [67]
# Socres: [0.6300741]
# Boundbox: [[182 139 174 316]]
# Class Id: [67]
# Socres: [0.53318447]
# Boundbox: [[180 138 176 317]]
# Class Id: [16]
# Socres: [0.57226497]
# Boundbox: [[316 143 320 337]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.69965637]
# Boundbox: [[172 143 190 324]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.56970567]
# Boundbox: [[145 127 179 344]]
# Class Id: [67 16]
# Socres: [0.5930118  0.57282066]
# Boundbox: [[140 124 178 348]
#  [312 153 209 320]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.87282574]
# Boundbox: [[135 129 183 341]]
# Class Id: [67]
# Socres: [0.527763]
# Boundbox: [[132 124 183 349]]
# Class Id: [67]
# Socres: [0.6989319]
# Boundbox: [[131 128 182 341]]
# Class Id: [67]
# Socres: [0.61097735]
# Boundbox: [[126 124 193 352]]
# Class Id: [67]
# Socres: [0.7815806]
# Boundbox: [[134 126 178 346]]
# Class Id: [67]
# Socres: [0.8009573]
# Boundbox: [[131 127 183 341]]
# Class Id: [67 16]
# Socres: [0.5522368 0.5013147]
# Boundbox: [[129 124 187 349]
#  [302 154 223 325]]
# Class Id: [67]
# Socres: [0.64860606]
# Boundbox: [[132 122 187 352]]
# Class Id: [67 16]
# Socres: [0.5860919 0.6337543]
# Boundbox: [[138 125 183 351]
#  [305 137 330 343]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.52767366]
# Boundbox: [[303 140 332 340]]
# Class Id: [67]
# Socres: [0.6570727]
# Boundbox: [[135 121 184 356]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67 16]
# Socres: [0.6453706 0.5447568]
# Boundbox: [[123 127 196 345]
#  [299 152 227 320]]
# Class Id: [16]
# Socres: [0.51326746]
# Boundbox: [[304 150 217 321]]
# Class Id: [67]
# Socres: [0.70715994]
# Boundbox: [[134 128 179 344]]
# Class Id: [67]
# Socres: [0.6232869]
# Boundbox: [[129 120 186 359]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.76410425]
# Boundbox: [[134 126 181 347]]
# Class Id: [67 16]
# Socres: [0.76957566 0.52287775]
# Boundbox: [[138 125 176 347]
#  [299 150 223 330]]
# Class Id: [67]
# Socres: [0.5893201]
# Boundbox: [[123 124 192 349]]
# Class Id: [67]
# Socres: [0.7831201]
# Boundbox: [[137 127 180 343]]
# Class Id: [67]
# Socres: [0.824677]
# Boundbox: [[132 127 186 347]]
# Class Id: [67]
# Socres: [0.77518004]
# Boundbox: [[136 125 181 350]]
# Class Id: [67 16]
# Socres: [0.8401359 0.5682906]
# Boundbox: [[130 130 188 340]
#  [316 161 196 307]]
# Class Id: [67]
# Socres: [0.6123131]
# Boundbox: [[131 121 196 359]]
# Class Id: [67]
# Socres: [0.6903725]
# Boundbox: [[134 130 184 341]]
# Class Id: [67]
# Socres: [0.7164496]
# Boundbox: [[137 125 181 349]]
# Class Id: [67]
# Socres: [0.7202109]
# Boundbox: [[132 130 186 338]]
# Class Id: [67 16]
# Socres: [0.8121254 0.5152141]
# Boundbox: [[135 126 182 349]
#  [313 151 197 319]]
# Class Id: [67]
# Socres: [0.7837699]
# Boundbox: [[136 127 184 344]]
# Class Id: [67]
# Socres: [0.8420573]
# Boundbox: [[132 125 187 348]]
# Class Id: [67]
# Socres: [0.61526054]
# Boundbox: [[132 122 185 352]]
# Class Id: [67]
# Socres: [0.5718874]
# Boundbox: [[125 129 206 345]]
# Class Id: [67 16]
# Socres: [0.6398464  0.51137745]
# Boundbox: [[133 126 188 344]
#  [312 155 203 319]]
# Class Id: [67]
# Socres: [0.7541376]
# Boundbox: [[136 130 179 339]]
# Class Id: [67]
# Socres: [0.8773858]
# Boundbox: [[135 125 183 347]]
# Class Id: [67 16]
# Socres: [0.7184308 0.566972 ]
# Boundbox: [[129 125 194 351]
#  [316 155 201 319]]
# Class Id: [67]
# Socres: [0.79661757]
# Boundbox: [[135 127 185 343]]
# Class Id: [67]
# Socres: [0.78024334]
# Boundbox: [[133 125 186 347]]
# Class Id: [67]
# Socres: [0.6089319]
# Boundbox: [[137 127 181 343]]
# Class Id: [67]
# Socres: [0.81571925]
# Boundbox: [[133 125 185 344]]
# Class Id: [67 16]
# Socres: [0.6142644 0.5414285]
# Boundbox: [[134 126 187 348]
#  [309 140 327 340]]
# Class Id: [67]
# Socres: [0.6461048]
# Boundbox: [[131 127 189 345]]
# Class Id: [67]
# Socres: [0.7219449]
# Boundbox: [[135 129 181 340]]
# Class Id: [67]
# Socres: [0.5443094]
# Boundbox: [[132 128 188 342]]
# Class Id: [67]
# Socres: [0.6080484]
# Boundbox: [[133 124 184 348]]
# Class Id: [16]
# Socres: [0.5175732]
# Boundbox: [[306 158 216 312]]
# Class Id: [67]
# Socres: [0.8061479]
# Boundbox: [[131 120 185 360]]
# Class Id: [67]
# Socres: [0.6603948]
# Boundbox: [[125 123 196 351]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.8495256]
# Boundbox: [[125 123 191 353]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.8641501]
# Boundbox: [[134 127 187 343]]
# Class Id: [67]
# Socres: [0.642324]
# Boundbox: [[123 124 198 350]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.6546271]
# Boundbox: [[133 122 185 356]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.50196904]
# Boundbox: [[303 157 245 315]]
# Class Id: [16]
# Socres: [0.5868016]
# Boundbox: [[313 132 324 348]]
# Class Id: [16]
# Socres: [0.5135914]
# Boundbox: [[322 154 196 314]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.54742646]
# Boundbox: [[182 149 181 328]]
# Class Id: ()
# Socres: ()
# Boundbox: ()

# %% [markdown]
# ### 6. Enhance the resolution to increase the accuracy

# %%
classNamesList = []

with open("dnn_model/classes.txt", "r") as fileObject:
    for className in fileObject.readlines():
        className = className.strip()
        classNamesList.append(className)

# print(classNamesList)
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox
        objectName = classNamesList[classId]
        cv2.putText(frame, f"{objectName}", 
                    (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")

    cv2.imshow("frames",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Class Id: [0]
# Socres: [0.502619]
# Boundbox: [[370 189 696 518]]
# Class Id: [0]
# Socres: [0.5563464]
# Boundbox: [[393 191 641 515]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.5642413  0.50711745]
# Boundbox: [[375 187 680 520]
#  [253 184 934 536]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55231875]
# Boundbox: [[417 178 591 538]]
# Class Id: [0]
# Socres: [0.6042659]
# Boundbox: [[396 190 627 512]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.60594875]
# Boundbox: [[379 192 677 511]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5276398]
# Boundbox: [[390 186 646 519]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.52623916]
# Boundbox: [[369 178 696 536]]
# Class Id: [0]
# Socres: [0.65418524]
# Boundbox: [[375 181 688 530]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5112985]
# Boundbox: [[384 181 671 535]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5661955]
# Boundbox: [[356 193 726 519]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.7827847  0.62572306]
# Boundbox: [[342 190 732 528]
#  [248 186 931 534]]
# Class Id: [0]
# Socres: [0.61581457]
# Boundbox: [[360 202 702 505]]
# Class Id: [0]
# Socres: [0.7462092]
# Boundbox: [[376 197 682 513]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50577533]
# Boundbox: [[396 187 640 529]]
# Class Id: [0]
# Socres: [0.62975293]
# Boundbox: [[362 192 706 515]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.60923964]
# Boundbox: [[363 186 701 534]]
# Class Id: [0 0]
# Socres: [0.5918266 0.6024796]
# Boundbox: [[343 198 745 506]
#  [239 187 969 533]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.5956276 0.6054077]
# Boundbox: [[353 190 734 529]
#  [256 188 927 532]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.5521755  0.58785313]
# Boundbox: [[362 190 713 520]
#  [242 189 944 530]]
# Class Id: [0 0]
# Socres: [0.5216701 0.5352646]
# Boundbox: [[351 188 740 526]
#  [243 190 940 529]]
# Class Id: [0]
# Socres: [0.5622855]
# Boundbox: [[243 180 945 540]]
# Class Id: [0]
# Socres: [0.5035992]
# Boundbox: [[240 186 940 534]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55179036]
# Boundbox: [[243 182 936 538]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6069979]
# Boundbox: [[368 198 707 504]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.6480068  0.52604085]
# Boundbox: [[346 198 738 506]
#  [246 190 937 530]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5175318]
# Boundbox: [[356 190 718 517]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5479778]
# Boundbox: [[384 184 669 526]]
# Class Id: [0 0]
# Socres: [0.5086417 0.5345076]
# Boundbox: [[409 182 622 527]
#  [246 172 943 548]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0 0]
# Socres: [0.6378952 0.6214379]
# Boundbox: [[372 178 687 539]
#  [241 174 940 546]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5514527]
# Boundbox: [[398 182 630 526]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.57691973]
# Boundbox: [[425 203 553 494]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5701867]
# Boundbox: [[418 195 576 507]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5672349]
# Boundbox: [[340 192 494 513]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [28]
# Socres: [0.5088367]
# Boundbox: [[422 230 833 468]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6426515]
# Boundbox: [[318 470 583 250]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5377509]
# Boundbox: [[310 447 612 273]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5325054]
# Boundbox: [[311 444 595 276]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.50045574]
# Boundbox: [[305 450 610 270]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.59009993]
# Boundbox: [[329 459 570 261]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5065862]
# Boundbox: [[533 216 307 494]]
# Class Id: [0]
# Socres: [0.5245734]
# Boundbox: [[489 205 417 514]]
# Class Id: [0]
# Socres: [0.5020638]
# Boundbox: [[460 212 497 501]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [28]
# Socres: [0.5020572]
# Boundbox: [[  2  17 280 489]]
# Class Id: [28]
# Socres: [0.6748746]
# Boundbox: [[515 106 613 582]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.66935927]
# Boundbox: [[320 349 556 364]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [28]
# Socres: [0.5154161]
# Boundbox: [[  2   8 278 490]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6480933]
# Boundbox: [[435  25  68  73]]
# Class Id: [0]
# Socres: [0.5890269]
# Boundbox: [[436  27  68  72]]
# Class Id: [0]
# Socres: [0.5391574]
# Boundbox: [[436  31  67  73]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.550112]
# Boundbox: [[438  30  65  73]]
# Class Id: [0]
# Socres: [0.66205585]
# Boundbox: [[437  31  64  70]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.582482]
# Boundbox: [[437  30  68  71]]
# Class Id: [0]
# Socres: [0.586817]
# Boundbox: [[435  28  68  74]]
# Class Id: [28  0]
# Socres: [0.5112453 0.5682596]
# Boundbox: [[  4  70 274 476]
#  [437  30  67  73]]
# Class Id: [0]
# Socres: [0.63392496]
# Boundbox: [[433  31  70  73]]
# Class Id: [0]
# Socres: [0.63729507]
# Boundbox: [[436  30  69  74]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5160793]
# Boundbox: [[458 225 467 483]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5199582]
# Boundbox: [[380   0  92  57]]
# Class Id: [0]
# Socres: [0.6088164]
# Boundbox: [[377   0  97  60]]
# Class Id: [67  0]
# Socres: [0.55750406 0.52248156]
# Boundbox: [[198  41 329 610]
#  [379   0  94  58]]
# Class Id: [67 67  0]
# Socres: [0.52994066 0.54089886 0.6053035 ]
# Boundbox: [[209  43 315 602]
#  [199  76 328 616]
#  [379   0  94  57]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5345052]
# Boundbox: [[379   0  94  56]]
# Class Id: [0]
# Socres: [0.51849073]
# Boundbox: [[298   0  96  64]]
# Class Id: [67  0  0]
# Socres: [0.633317  0.5584922 0.543595 ]
# Boundbox: [[180  67 316 621]
#  [293   0 112  63]
#  [383   0  90  56]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67  0]
# Socres: [0.64151096 0.504035  ]
# Boundbox: [[211  62 291 626]
#  [284   0 125  62]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.56761056]
# Boundbox: [[191  69 307 628]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.59222436]
# Boundbox: [[193  64 306 630]]
# Class Id: [67]
# Socres: [0.6229469]
# Boundbox: [[206  72 293 615]]
# Class Id: [67]
# Socres: [0.72905606]
# Boundbox: [[202  75 301 615]]
# Class Id: [67]
# Socres: [0.5128099]
# Boundbox: [[199  72 298 620]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.51359975]
# Boundbox: [[200  69 299 616]]
# Class Id: [67]
# Socres: [0.5254714]
# Boundbox: [[198  69 302 617]]
# Class Id: [67]
# Socres: [0.66855574]
# Boundbox: [[197  71 295 612]]
# Class Id: [67]
# Socres: [0.5603384]
# Boundbox: [[200  69 302 618]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67  0]
# Socres: [0.57361096 0.51120836]
# Boundbox: [[193  65 296 629]
#  [521 226 334 474]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5872404]
# Boundbox: [[199  67 301 621]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.60844713]
# Boundbox: [[198  69 298 617]]
# Class Id: [67]
# Socres: [0.5825012]
# Boundbox: [[181  76 319 607]]
# Class Id: [67]
# Socres: [0.71620667]
# Boundbox: [[200  73 295 615]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.62454003]
# Boundbox: [[210  68 291 619]]
# Class Id: [67]
# Socres: [0.5043795]
# Boundbox: [[190  67 312 620]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.51950514]
# Boundbox: [[179  61 325 631]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.63659465]
# Boundbox: [[187  58 309 633]]
# Class Id: [67]
# Socres: [0.71193105]
# Boundbox: [[177  70 318 615]]
# Class Id: [67]
# Socres: [0.64090425]
# Boundbox: [[199  76 297 606]]
# Class Id: [67]
# Socres: [0.72442806]
# Boundbox: [[171  73 327 611]]
# Class Id: [67]
# Socres: [0.7670302]
# Boundbox: [[186  75 307 608]]
# Class Id: [67]
# Socres: [0.673527]
# Boundbox: [[175  74 323 610]]
# Class Id: [67]
# Socres: [0.6645708]
# Boundbox: [[159  79 338 608]]
# Class Id: [67]
# Socres: [0.76331526]
# Boundbox: [[172  76 327 613]]
# Class Id: [67]
# Socres: [0.5623147]
# Boundbox: [[171  75 316 607]]
# Class Id: [67]
# Socres: [0.6660886]
# Boundbox: [[150  66 353 627]]
# Class Id: [67]
# Socres: [0.7383285]
# Boundbox: [[166  85 329 593]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.70663893]
# Boundbox: [[164  86 333 593]]
# Class Id: [67]
# Socres: [0.8141105]
# Boundbox: [[180  83 312 594]]
# Class Id: [67]
# Socres: [0.5632975]
# Boundbox: [[157  77 335 612]]
# Class Id: [67]
# Socres: [0.58311975]
# Boundbox: [[159  78 339 604]]
# Class Id: [67]
# Socres: [0.57486516]
# Boundbox: [[145  72 355 610]]
# Class Id: [67]
# Socres: [0.5572255]
# Boundbox: [[162  80 331 600]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.58330417]
# Boundbox: [[159  89 327 594]]
# Class Id: [67]
# Socres: [0.69973624]
# Boundbox: [[153  87 333 590]]
# Class Id: [67]
# Socres: [0.63468575]
# Boundbox: [[163  85 317 589]]
# Class Id: [67]
# Socres: [0.6885774]
# Boundbox: [[165  86 325 591]]
# Class Id: [67]
# Socres: [0.8503582]
# Boundbox: [[182  87 311 596]]
# Class Id: [67]
# Socres: [0.6385291]
# Boundbox: [[166  78 324 604]]
# Class Id: [67]
# Socres: [0.6483267]
# Boundbox: [[157  78 333 605]]
# Class Id: [67]
# Socres: [0.619123]
# Boundbox: [[140  77 352 609]]
# Class Id: [67]
# Socres: [0.7222203]
# Boundbox: [[158  87 334 594]]
# Class Id: [67]
# Socres: [0.7746964]
# Boundbox: [[177  82 318 606]]
# Class Id: [67]
# Socres: [0.81354904]
# Boundbox: [[177  85 317 600]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.65255725]
# Boundbox: [[155  91 338 585]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.67486686]
# Boundbox: [[165  93 329 581]]
# Class Id: [67]
# Socres: [0.5246545]
# Boundbox: [[187  53 345 586]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55239123]
# Boundbox: [[406 244 593 461]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6044819]
# Boundbox: [[492 214 409 494]]
# Class Id: [0]
# Socres: [0.50001734]
# Boundbox: [[508 213 344 486]]
# Class Id: [0]
# Socres: [0.58448416]
# Boundbox: [[511 216 370 491]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.62325424]
# Boundbox: [[492 218 386 486]]
# Class Id: [0]
# Socres: [0.50484717]
# Boundbox: [[497 202 403 511]]
# Class Id: [0]
# Socres: [0.62970227]
# Boundbox: [[495 209 432 496]]
# Class Id: [0]
# Socres: [0.54779506]
# Boundbox: [[493 205 405 505]]
# Class Id: [0]
# Socres: [0.62642163]
# Boundbox: [[505 205 385 497]]
# Class Id: [0]
# Socres: [0.5950239]
# Boundbox: [[472 206 456 498]]
# Class Id: [0]
# Socres: [0.57792276]
# Boundbox: [[497 212 411 489]]
# Class Id: [0]
# Socres: [0.51029855]
# Boundbox: [[469 204 460 502]]
# Class Id: [0]
# Socres: [0.62237686]
# Boundbox: [[469 201 438 505]]
# Class Id: [0]
# Socres: [0.5157627]
# Boundbox: [[449 204 498 505]]
# Class Id: [0]
# Socres: [0.5276839]
# Boundbox: [[479 202 446 502]]
# Class Id: [0]
# Socres: [0.56730145]
# Boundbox: [[499 212 399 489]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5084042]
# Boundbox: [[464 200 482 508]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.62342745]
# Boundbox: [[471 205 449 496]]
# Class Id: [0]
# Socres: [0.5602758]
# Boundbox: [[465 198 462 506]]
# Class Id: [0]
# Socres: [0.5357962]
# Boundbox: [[463 194 507 517]]
# Class Id: [0]
# Socres: [0.56900024]
# Boundbox: [[470 200 477 501]]
# Class Id: [0]
# Socres: [0.5956592]
# Boundbox: [[488 196 431 510]]
# Class Id: [0]
# Socres: [0.5766537]
# Boundbox: [[466 197 481 514]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5079906]
# Boundbox: [[463 207 483 496]]
# Class Id: [0]
# Socres: [0.59780025]
# Boundbox: [[489 216 442 487]]
# Class Id: [0]
# Socres: [0.5071406]
# Boundbox: [[485 209 434 499]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.69966424]
# Boundbox: [[507 213 392 492]]
# Class Id: [0]
# Socres: [0.5625959]
# Boundbox: [[466 210 479 504]]
# Class Id: [0]
# Socres: [0.57679343]
# Boundbox: [[506 219 412 488]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.57370985]
# Boundbox: [[489 218 444 501]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.53598154]
# Boundbox: [[482 215 433 491]]
# Class Id: [0]
# Socres: [0.556162]
# Boundbox: [[482 206 437 504]]
# Class Id: [0]
# Socres: [0.50379735]
# Boundbox: [[494 210 408 493]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.73038024]
# Boundbox: [[474 212 446 484]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5983255]
# Boundbox: [[146 107 347 571]]
# Class Id: [67  0]
# Socres: [0.7414057  0.50279975]
# Boundbox: [[189 111 337 582]
#  [455 218 455 496]]
# Class Id: [0]
# Socres: [0.54885405]
# Boundbox: [[528 220 338 492]]
# Class Id: [67  0]
# Socres: [0.6083689 0.6467448]
# Boundbox: [[254 170 303 497]
#  [505 218 428 487]]
# Class Id: [0]
# Socres: [0.5647326]
# Boundbox: [[511 224 424 486]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.66332227]
# Boundbox: [[525 220 360 483]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5652755]
# Boundbox: [[485 219 463 491]]
# Class Id: [0]
# Socres: [0.58704436]
# Boundbox: [[534 221 336 482]]
# Class Id: [0]
# Socres: [0.5612053]
# Boundbox: [[589 245 260 465]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5059114]
# Boundbox: [[445  41 306 611]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.74463326]
# Boundbox: [[382  68 353 633]]
# Class Id: [67]
# Socres: [0.749639]
# Boundbox: [[347  82 384 610]]
# Class Id: [67]
# Socres: [0.54572314]
# Boundbox: [[349  68 372 630]]
# Class Id: [67]
# Socres: [0.59186286]
# Boundbox: [[366  80 357 609]]
# Class Id: [67 28]
# Socres: [0.5682411  0.51375896]
# Boundbox: [[352  86 367 608]
#  [369 381 306 304]]
# Class Id: [67 28]
# Socres: [0.5383797 0.5323814]
# Boundbox: [[337  82 394 619]
#  [364 382 316 303]]
# Class Id: [67]
# Socres: [0.6573203]
# Boundbox: [[353  78 359 621]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.84343326]
# Boundbox: [[344  83 377 615]]
# Class Id: [67]
# Socres: [0.5569542]
# Boundbox: [[359  81 363 612]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.6096641]
# Boundbox: [[344  86 381 615]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.5345265]
# Boundbox: [[342  80 383 628]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [67]
# Socres: [0.53743666]
# Boundbox: [[336  88 391 616]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [24]
# Socres: [0.5234434]
# Boundbox: [[617 248 661 454]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.7456973]
# Boundbox: [[538 313 363 406]]
# Class Id: [0]
# Socres: [0.50838315]
# Boundbox: [[424  17  63  68]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5354818]
# Boundbox: [[422  27  60  67]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5230986]
# Boundbox: [[424  26  61  66]]
# Class Id: [0]
# Socres: [0.5654284]
# Boundbox: [[423  25  65  69]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5424597]
# Boundbox: [[524 262 347 454]]
# Class Id: [0 0]
# Socres: [0.58322114 0.52561766]
# Boundbox: [[521 259 336 458]
#  [424  26  64  69]]
# Class Id: [0]
# Socres: [0.5121674]
# Boundbox: [[505 258 355 462]]
# Class Id: [0 0]
# Socres: [0.64210624 0.5111585 ]
# Boundbox: [[498 260 360 456]
#  [425  24  61  70]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5488046]
# Boundbox: [[421  26  65  68]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5107644]
# Boundbox: [[283 209 594 503]]
# Class Id: [34  0]
# Socres: [0.5618683  0.50936955]
# Boundbox: [[313  91 286 444]
#  [474 218 416 487]]
# Class Id: [34]
# Socres: [0.56089574]
# Boundbox: [[317  90 280 440]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5318472]
# Boundbox: [[306 221 576 485]]
# Class Id: [0]
# Socres: [0.5877542]
# Boundbox: [[472 215 445 487]]
# Class Id: [27]
# Socres: [0.58026755]
# Boundbox: [[224  42 122 453]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.51257217]
# Boundbox: [[485 220 396 482]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [27]
# Socres: [0.5691992]
# Boundbox: [[225  27 122 486]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [27]
# Socres: [0.5440011]
# Boundbox: [[228  83 115 438]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [27]
# Socres: [0.52483696]
# Boundbox: [[223  33 120 476]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.603787]
# Boundbox: [[471 218 427 492]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.52180153]
# Boundbox: [[449 210 433 493]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [27]
# Socres: [0.5146497]
# Boundbox: [[224  40 120 458]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.6391695]
# Boundbox: [[431 394  56  62]]
# Class Id: [0]
# Socres: [0.61115855]
# Boundbox: [[430 397  57  60]]
# Class Id: [0]
# Socres: [0.6140001]
# Boundbox: [[429 396  57  62]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.53691]
# Boundbox: [[212 232 407 477]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.593183]
# Boundbox: [[284 240 341 469]]
# Class Id: [0]
# Socres: [0.7287523]
# Boundbox: [[272 264 333 447]]
# Class Id: [0]
# Socres: [0.5615581]
# Boundbox: [[280 258 326 454]]
# Class Id: [0]
# Socres: [0.6649874]
# Boundbox: [[284 266 318 447]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55593246]
# Boundbox: [[272 248 333 461]]
# Class Id: [0]
# Socres: [0.5748238]
# Boundbox: [[276 259 319 446]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5742503]
# Boundbox: [[274 251 329 461]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [28 28]
# Socres: [0.5200347 0.5040212]
# Boundbox: [[  6 427 269 283]
#  [  6 442 266 278]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.58669466]
# Boundbox: [[292 248 317 465]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.58641934]
# Boundbox: [[324 237 294 471]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.64423865]
# Boundbox: [[351 226 266 493]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.53914756]
# Boundbox: [[430 395  67  60]]
# Class Id: [0]
# Socres: [0.5412889]
# Boundbox: [[429 397  63  58]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5241162]
# Boundbox: [[430 398  60  55]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5053682]
# Boundbox: [[435 397  59  57]]
# Class Id: [0]
# Socres: [0.5315503]
# Boundbox: [[432 400  58  54]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.620635]
# Boundbox: [[431 399  58  55]]
# Class Id: [0]
# Socres: [0.55424345]
# Boundbox: [[432 399  57  55]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5336209]
# Boundbox: [[415 392  76  65]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [16]
# Socres: [0.6115706]
# Boundbox: [[542 354 503 360]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.55038697]
# Boundbox: [[556 245 368 473]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.587001]
# Boundbox: [[ 164   70 1054  650]]
# Class Id: [0]
# Socres: [0.5119942]
# Boundbox: [[ 175   70 1035  650]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.510521]
# Boundbox: [[ 143   65 1095  655]]
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: ()
# Socres: ()
# Boundbox: ()
# Class Id: [0]
# Socres: [0.5851448]
# Boundbox: [[ 178   83 1022  637]]
# Class Id: [0]
# Socres: [0.74224025]
# Boundbox: [[212  60 983 660]]
# Class Id: [0]
# Socres: [0.6239491]
# Boundbox: [[ 175   74 1034  646]]
# Class Id: [0]
# Socres: [0.5999302]
# Boundbox: [[200  77 995 643]]

# %% [markdown]
# ### 7. Now Create Interactive Buttons to detect specific object

# %% [markdown]
# ## **<center><font style="color:rgb(100,109,254)">Full Code</font> </center>**

# %%
import cv2
import numpy as np

classNamesList = []

with open("dnn_model/classes.txt", "r") as fileObject:
    for className in fileObject.readlines():
        className = className.strip()
        classNamesList.append(className)

# print(classNamesList)
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

buttonPerson = False
buttonCell = False
buttonRemote = False

def clickButton(event, x, y, flags, params):
    global buttonPerson, buttonCell, buttonRemote
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,y)

        polygon = np.array([[(20, 20), (210, 20), (210, 70), (20, 70)]])
        polygon1 = np.array([[(20, 80), (220, 80), (210, 130), (20, 130)]])
        polygon2 = np.array([[(20, 140), (220, 140), (210, 190), (20, 190)]])

        isInside = cv2.pointPolygonTest(polygon, (x, y), False)
        isInside1 = cv2.pointPolygonTest(polygon1, (x, y), False)
        isInside2 = cv2.pointPolygonTest(polygon2, (x, y), False)

        if isInside > 0:
            print("inside")

            if buttonPerson is False:
                buttonPerson = True
            else:
                buttonPerson = False

            print("Person Button: ", buttonPerson)
        
        if isInside1 > 0:
            print("inside")

            if buttonCell is False:
                buttonCell = True
            else:
                buttonCell = False

            print("Cell Button: ", buttonCell)
        
        if isInside2 > 0:
            print("inside")

            if buttonRemote is False:
                buttonRemote = True
            else:
                buttonRemote = False

            print("Remote Button: ", buttonRemote)


# create window
cv2.namedWindow("Frame")
cv2.setMouseCallback("Frame", clickButton)

while True:

    _, frame = cap.read()

    (clasIds, scores, bboxes) = model.detect(frame)

    for classId, score, bbox in zip(clasIds, scores, bboxes):

        score = round(score, 2)
        x, y, w, h = bbox
        objectName = classNamesList[classId]

        if objectName == "person" and buttonPerson is True:
            cv2.putText(frame, f"{objectName}", 
                        (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
        
        if objectName == "cell phone" and buttonCell is True:
            cv2.putText(frame, f"{objectName}", 
                        (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
        
        if objectName == "remote" and buttonRemote is True:
            cv2.putText(frame, f"{objectName}", 
                        (x-5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
    
    
    # print(f"Class Id: {clasIds}\nSocres: {scores}\nBoundbox: {bboxes}")
    # Create BUtton
    # cv2.rectangle(frame, (20, 20),(210, 70), (200,0,200), -1)
    polygon = np.array([[(20, 20), (220, 20), (210, 70), (20, 70)]])
    cv2.fillPoly(frame, polygon, (200, 0, 200))
    cv2.putText(frame, "Person", (30, 60), cv2.FONT_HERSHEY_PLAIN, 3, (255, 255, 255), 3)

    polygon1 = np.array([[(20, 80), (220, 80), (210, 130), (20, 130)]])
    cv2.fillPoly(frame, polygon1, (200, 0, 200))
    cv2.putText(frame, "Phone", (30, 120), cv2.FONT_HERSHEY_PLAIN, 3, (255, 255, 255), 3)

    polygon2 = np.array([[(20, 140), (220, 140), (210, 190), (20, 190)]])
    cv2.fillPoly(frame, polygon2, (200, 0, 200))
    cv2.putText(frame, "Remote", (30, 180), cv2.FONT_HERSHEY_PLAIN, 3, (255, 255, 255), 3)


    cv2.imshow("Frame",frame)

    key = cv2.waitKey(1)

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 171 105
# inside
# Cell Button:  True
# 152 166
# inside
# Remote Button:  True
